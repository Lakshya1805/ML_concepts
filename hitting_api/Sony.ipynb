# %%
import pandas as pd

# %%
import requests

url = "https://indian-tv-schedule.p.rapidapi.com/Schedule"

querystring = {"channel":"Sony HD"}

headers = {
	"X-RapidAPI-Key": "1f70a230d9mshaab14c143100d85p1f2f84jsn3406e179e588",
	"X-RapidAPI-Host": "indian-tv-schedule.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'00:00:00': {'name': 'Best Of Crime Patrol', 'other-details': "Some of the best cases of 'Crime Patrol', which investigates how innocent people turn into criminals due to the influence of evil in society.", 'type': 'TV Show'}, '01:20:00': {'name': 'Best Of Crime Patrol', 'other-details': "Some of the best cases of 'Crime Patrol', which investigates how innocent people turn into criminals due to the influence of evil in society.", 'type': 'TV Show'}, '02:00:00': {'name': 'Best Of Crime Patrol', 'other-details': "Some of the best cases of 'Crime Patrol', which investigates how innocent people turn into criminals due to the influence of evil in society.", 'type': 'TV Show'}, '02:40:00': {'name': 'Best Of Crime Patrol', 'other-details': "Some of the best cases of 'Crime Patrol', which investigates how innocent people turn into criminals due to the influence of evil in society.", 'type': 'TV Show'}, '04:00:00': {'name': 'Best Of Crime Patrol', 'other-details': "Some of the best cases of 
# ...

# %%
df = pd.DataFrame(response.json())

# %%
df
# Out:
#                                                         00:00:00  \
# name                                        Best Of Crime Patrol
# other-details  Some of the best cases of 'Crime Patrol', whic...
# type                                                     TV Show
#
#                                                         01:20:00  \
# name                                        Best Of Crime Patrol
# other-details  Some of the best cases of 'Crime Patrol', whic...
# type                                                     TV Show
#
#                                                         02:00:00  \
# name                                        Best Of Crime Patrol
# other-details  Some of the best cases of 'Crime Patrol', whic...
# type                                                     TV Show
#
#                                                         02:40:00  \
# name                                        Best Of Crime Patrol
# ...

# %%
df.to_csv('SonySchedule.csv')
